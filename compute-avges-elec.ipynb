# %%
import sys
sys.path.append('/scratch/rpradata/PressureEv/Simulations')

from Turbcopy.p3d import p3d

import numpy as np

import matplotlib.pyplot as plt

from numpy import newaxis as nna

from scipy.stats import norm

import matplotlib.mlab as mlab

import h5py

import pandas as pd

# %%
# with h5py.File("/scratch/rpradata/PressureEv/Simulations/rhlh_terms_elec_xx.h5", "r") as f:
#     # read full array at timestep 10
#     conv10 = f["conv"][2, :, :]
#     BWP10 = f["BWP"][2, :, :]
#     DP10 = f["DP"][2, :, :]
#     comp10 = f["comp"][2, :, :]

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/fixed_tensors_xx/fix_rhlh_terms_elec_xx.h5", "r") as f: #EDIT AS NAMED
    # read full array at timestep 0
    # conv0 = f["conv"][0, :, :]

    #with all timesteps:
    conv = f["conv"]
    BWP = f['BWP']
    DP = f['DP']
    comp = f['comp']

    # read a smaller subregion without loading the entire file
    # subregion = f["BWP"][10, 0:512, 0:512]

    # check shape
    # print(conv0.shape, convt.shape, len(convt))

    conv_out = np.zeros(conv.shape[1:], dtype=np.float64)
    BWP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    DP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    comp_out = np.zeros(conv.shape[1:], dtype=np.float64)

    for t in range(conv.shape[0]):     # loop over time axis
        conv_out += conv[t, :, :]          # adds one 4096x4096 slice at a time
        BWP_out += BWP[t, :, :]
        DP_out += DP[t, :, :]
        comp_out += comp[t, :, :]

# out now holds the time-sum, shape (4096, 4096)


###

conv_avg = conv_out / 119
BWP_avg = BWP_out / 119
DP_avg = DP_out / 119
comp_avg = comp_out / 119

##

k = 1  # number of timesteps (change if needed)
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/fixed_tensors_xx/sumavg_vals_elec_xx.h5", "w") as f: #EDIT THIS
    f.create_dataset("conv", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("BWP",  (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("DP",   (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("comp", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/fixed_tensors_xx/sumavg_vals_elec_xx.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["conv"][0, :, :] = conv_avg.astype(np.float32)
    f["BWP"][0, :, :]  = BWP_avg.astype(np.float32)
    f["DP"][0, :, :]   = DP_avg.astype(np.float32)
    f["comp"][0, :, :] = comp_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/rhlh_terms_elec_yy.h5", "r") as f: #EDIT AS NAMED
    # read full array at timestep 0
    # conv0 = f["conv"][0, :, :]

    #with all timesteps:
    conv = f["conv"]
    BWP = f['BWP']
    DP = f['DP']
    comp = f['comp']

    # read a smaller subregion without loading the entire file
    # subregion = f["BWP"][10, 0:512, 0:512]

    # check shape
    # print(conv0.shape, convt.shape, len(convt))

    conv_out = np.zeros(conv.shape[1:], dtype=np.float64)
    BWP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    DP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    comp_out = np.zeros(conv.shape[1:], dtype=np.float64)

    for t in range(conv.shape[0]):     # loop over time axis
        conv_out += conv[t, :, :]          # adds one 4096x4096 slice at a time
        BWP_out += BWP[t, :, :]
        DP_out += DP[t, :, :]
        comp_out += comp[t, :, :]

# out now holds the time-sum, shape (4096, 4096)


###

conv_avg = conv_out / 119
BWP_avg = BWP_out / 119
DP_avg = DP_out / 119
comp_avg = comp_out / 119

##

k = 1  # number of timesteps (change if needed)
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_yy.h5", "w") as f: #EDIT THIS
    f.create_dataset("conv", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("BWP",  (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("DP",   (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("comp", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_yy.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["conv"][0, :, :] = conv_avg.astype(np.float32)
    f["BWP"][0, :, :]  = BWP_avg.astype(np.float32)
    f["DP"][0, :, :]   = DP_avg.astype(np.float32)
    f["comp"][0, :, :] = comp_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/rhlh_terms_elec_zz.h5", "r") as f: #EDIT AS NAMED
    # read full array at timestep 0
    # conv0 = f["conv"][0, :, :]

    #with all timesteps:
    conv = f["conv"]
    BWP = f['BWP']
    DP = f['DP']
    comp = f['comp']

    # read a smaller subregion without loading the entire file
    # subregion = f["BWP"][10, 0:512, 0:512]

    # check shape
    # print(conv0.shape, convt.shape, len(convt))

    conv_out = np.zeros(conv.shape[1:], dtype=np.float64)
    BWP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    DP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    comp_out = np.zeros(conv.shape[1:], dtype=np.float64)

    for t in range(conv.shape[0]):     # loop over time axis
        conv_out += conv[t, :, :]          # adds one 4096x4096 slice at a time
        BWP_out += BWP[t, :, :]
        DP_out += DP[t, :, :]
        comp_out += comp[t, :, :]

# out now holds the time-sum, shape (4096, 4096)


###

conv_avg = conv_out / 119
BWP_avg = BWP_out / 119
DP_avg = DP_out / 119
comp_avg = comp_out / 119

##

k = 1  # number of timesteps (change if needed)
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_zz.h5", "w") as f: #EDIT THIS
    f.create_dataset("conv", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("BWP",  (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("DP",   (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("comp", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_zz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["conv"][0, :, :] = conv_avg.astype(np.float32)
    f["BWP"][0, :, :]  = BWP_avg.astype(np.float32)
    f["DP"][0, :, :]   = DP_avg.astype(np.float32)
    f["comp"][0, :, :] = comp_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/rhlh_terms_elec_xy.h5", "r") as f: #EDIT AS NAMED
    # read full array at timestep 0
    # conv0 = f["conv"][0, :, :]

    #with all timesteps:
    conv = f["conv"]
    BWP = f['BWP']
    DP = f['DP']
    comp = f['comp']

    # read a smaller subregion without loading the entire file
    # subregion = f["BWP"][10, 0:512, 0:512]

    # check shape
    # print(conv0.shape, convt.shape, len(convt))

    conv_out = np.zeros(conv.shape[1:], dtype=np.float64)
    BWP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    DP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    comp_out = np.zeros(conv.shape[1:], dtype=np.float64)

    for t in range(conv.shape[0]):     # loop over time axis
        conv_out += conv[t, :, :]          # adds one 4096x4096 slice at a time
        BWP_out += BWP[t, :, :]
        DP_out += DP[t, :, :]
        comp_out += comp[t, :, :]

# out now holds the time-sum, shape (4096, 4096)


###

conv_avg = conv_out / 119
BWP_avg = BWP_out / 119
DP_avg = DP_out / 119
comp_avg = comp_out / 119

##

k = 1  # number of timesteps (change if needed)
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_xx.h5", "w") as f: #EDIT THIS
    f.create_dataset("conv", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("BWP",  (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("DP",   (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("comp", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_xx.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["conv"][0, :, :] = conv_avg.astype(np.float32)
    f["BWP"][0, :, :]  = BWP_avg.astype(np.float32)
    f["DP"][0, :, :]   = DP_avg.astype(np.float32)
    f["comp"][0, :, :] = comp_avg.astype(np.float32)

# %%
def load_p_elec(tslice, datalink): #tsloce and link ues p3d from turbcopy
    rc = p3d(datalink, '000')
    rc.vars2load(['prim'])
    rc.loadslice(tslice)

    
    Pe_xx = rc.pexx.squeeze()
    Pe_xy = rc.pexy.squeeze()
    Pe_xz = rc.pexz.squeeze()
    Pe_yy = rc.peyy.squeeze()
    Pe_yz = rc.peyz.squeeze()
    Pe_zz = rc.pezz.squeeze()

    ny, nx = Pe_xx.shape #x and y here corresponding to the "spatial" coordinate. these will apply to all P_ij
    Pe_tensor = np.zeros((ny, nx, 3, 3)) #3 and 3 for axis 0 and 1.

    Pe_tensor[:, :, 0, 0] = Pe_xx  # P_xx
    Pe_tensor[:, :, 0, 1] = Pe_xy  # P_xy
    Pe_tensor[:, :, 0, 2] = Pe_xz  # P_xz

    Pe_tensor[:, :, 1, 0] = Pe_xy  # P_yx = P_xy
    Pe_tensor[:, :, 1, 1] = Pe_yy  # P_yy
    Pe_tensor[:, :, 1, 2] = Pe_yz  # P_yz

    Pe_tensor[:, :, 2, 0] = Pe_xz  # P_zx = P_xz
    Pe_tensor[:, :, 2, 1] = Pe_yz  # P_zy = P_yz
    Pe_tensor[:, :, 2, 2] = Pe_zz  # P_zz

    return Pe_tensor

# %%
datalink = '/archive/tulasi/149p6_rs/'
dt = 0.005

# %%
#avg for Pressure dpdt
k = 1
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xx.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,0,0]
Pixx = load_p_elec(1, datalink)[:,:,0,0]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xx.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_yy.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,1,1]
Pixx = load_p_elec(1, datalink)[:,:,1,1]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_yy.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_zz.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,2,2]
Pixx = load_p_elec(1, datalink)[:,:,2,2]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_zz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xy.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,0,1]
Pixx = load_p_elec(1, datalink)[:,:,0,1]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xy.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
def load_p_ion(tslice, datalink): #tsloce and link ues p3d from turbcopy
    rc = p3d(datalink, '000')
    rc.vars2load(['prim'])
    rc.loadslice(tslice)

    
    Pe_xx = rc.pixx.squeeze()
    Pe_xy = rc.pixy.squeeze()
    Pe_xz = rc.pixz.squeeze()
    Pe_yy = rc.piyy.squeeze()
    Pe_yz = rc.piyz.squeeze()
    Pe_zz = rc.pizz.squeeze()

    ny, nx = Pe_xx.shape #x and y here corresponding to the "spatial" coordinate. these will apply to all P_ij
    Pe_tensor = np.zeros((ny, nx, 3, 3)) #3 and 3 for axis 0 and 1.

    Pe_tensor[:, :, 0, 0] = Pe_xx  # P_xx
    Pe_tensor[:, :, 0, 1] = Pe_xy  # P_xy
    Pe_tensor[:, :, 0, 2] = Pe_xz  # P_xz

    Pe_tensor[:, :, 1, 0] = Pe_xy  # P_yx = P_xy
    Pe_tensor[:, :, 1, 1] = Pe_yy  # P_yy
    Pe_tensor[:, :, 1, 2] = Pe_yz  # P_yz

    Pe_tensor[:, :, 2, 0] = Pe_xz  # P_zx = P_xz
    Pe_tensor[:, :, 2, 1] = Pe_yz  # P_zy = P_yz
    Pe_tensor[:, :, 2, 2] = Pe_zz  # P_zz

    return Pe_tensor

# %%
#avg for Pressure dpdt
k = 1
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_xx.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_ion(118, datalink)[:,:,0,0]
Pixx = load_p_ion(1, datalink)[:,:,0,0]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_xx.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_yy.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_ion(118, datalink)[:,:,1,1]
Pixx = load_p_ion(1, datalink)[:,:,1,1]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_yy.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_xy.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_ion(118, datalink)[:,:,0,1]
Pixx = load_p_ion(1, datalink)[:,:,0,1]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_xy.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_zz.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_ion(118, datalink)[:,:,2,2]
Pixx = load_p_ion(1, datalink)[:,:,2,2]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_zz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_xz.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_ion(118, datalink)[:,:,0,2]
Pixx = load_p_ion(1, datalink)[:,:,0,2]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_xz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_yz.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_ion(118, datalink)[:,:,1,2]
Pixx = load_p_ion(1, datalink)[:,:,1,2]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/ion-terms/dpdt_ion/sumavg_dpdt_ion_yz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
#actually for electrons:

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xx.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,0,0]
Pixx = load_p_elec(1, datalink)[:,:,0,0]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xx.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_yy.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,1,1]
Pixx = load_p_elec(1, datalink)[:,:,1,1]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_yy.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)



with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_zz.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,2,2]
Pixx = load_p_elec(1, datalink)[:,:,2,2]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_zz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xy.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,0,1]
Pixx = load_p_elec(1, datalink)[:,:,0,1]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xy.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xz.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,0,2]
Pixx = load_p_elec(1, datalink)[:,:,0,2]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_xz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_yz.h5", "w") as f: #EDIT THIS
    f.create_dataset("dpdt avg", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)


Pfxx = load_p_elec(118, datalink)[:,:,1,2]
Pixx = load_p_elec(1, datalink)[:,:,1,2]

tf = dt * 118
ti = dt * 1

dPdt_avg = (Pfxx - Pixx) / (tf - ti)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/dpdt_elec/sumavg_dpdt_elec_yz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["dpdt avg"][0, :, :] = dPdt_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/rhlh_terms_elec_xz.h5", "r") as f: #EDIT AS NAMED
    # read full array at timestep 0
    # conv0 = f["conv"][0, :, :]

    #with all timesteps:
    conv = f["conv"]
    BWP = f['BWP']
    DP = f['DP']
    comp = f['comp']

    # read a smaller subregion without loading the entire file
    # subregion = f["BWP"][10, 0:512, 0:512]

    # check shape
    # print(conv0.shape, convt.shape, len(convt))

    conv_out = np.zeros(conv.shape[1:], dtype=np.float64)
    BWP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    DP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    comp_out = np.zeros(conv.shape[1:], dtype=np.float64)

    for t in range(conv.shape[0]):     # loop over time axis
        conv_out += conv[t, :, :]          # adds one 4096x4096 slice at a time
        BWP_out += BWP[t, :, :]
        DP_out += DP[t, :, :]
        comp_out += comp[t, :, :]

# out now holds the time-sum, shape (4096, 4096)


###

conv_avg = conv_out / 119
BWP_avg = BWP_out / 119
DP_avg = DP_out / 119
comp_avg = comp_out / 119

##

k = 1  # number of timesteps (change if needed)
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_xz.h5", "w") as f: #EDIT THIS
    f.create_dataset("conv", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("BWP",  (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("DP",   (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("comp", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_xz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["conv"][0, :, :] = conv_avg.astype(np.float32)
    f["BWP"][0, :, :]  = BWP_avg.astype(np.float32)
    f["DP"][0, :, :]   = DP_avg.astype(np.float32)
    f["comp"][0, :, :] = comp_avg.astype(np.float32)

# %%
with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/rhlh_terms_elec_yz.h5", "r") as f: #EDIT AS NAMED
    # read full array at timestep 0
    # conv0 = f["conv"][0, :, :]

    #with all timesteps:
    conv = f["conv"]
    BWP = f['BWP']
    DP = f['DP']
    comp = f['comp']

    # read a smaller subregion without loading the entire file
    # subregion = f["BWP"][10, 0:512, 0:512]

    # check shape
    # print(conv0.shape, convt.shape, len(convt))

    conv_out = np.zeros(conv.shape[1:], dtype=np.float64)
    BWP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    DP_out = np.zeros(conv.shape[1:], dtype=np.float64)
    comp_out = np.zeros(conv.shape[1:], dtype=np.float64)

    for t in range(conv.shape[0]):     # loop over time axis
        conv_out += conv[t, :, :]          # adds one 4096x4096 slice at a time
        BWP_out += BWP[t, :, :]
        DP_out += DP[t, :, :]
        comp_out += comp[t, :, :]

# out now holds the time-sum, shape (4096, 4096)


###

conv_avg = conv_out / 119
BWP_avg = BWP_out / 119
DP_avg = DP_out / 119
comp_avg = comp_out / 119

##

k = 1  # number of timesteps (change if needed)
ny, nx = 4096, 4096

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_yz.h5", "w") as f: #EDIT THIS
    f.create_dataset("conv", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("BWP",  (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("DP",   (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)
    f.create_dataset("comp", (k, ny, nx), dtype='float32',
                     chunks=(1, 256, 256), compression="gzip", compression_opts=4)

with h5py.File("/scratch/rpradata/PressureEv/Simulations/electron-terms/sumavg_vals_elec_yz.h5", "a") as f:  # "a" = append/update mode #EDIT THIS TOO
    f["conv"][0, :, :] = conv_avg.astype(np.float32)
    f["BWP"][0, :, :]  = BWP_avg.astype(np.float32)
    f["DP"][0, :, :]   = DP_avg.astype(np.float32)
    f["comp"][0, :, :] = comp_avg.astype(np.float32)
